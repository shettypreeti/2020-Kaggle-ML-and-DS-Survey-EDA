# %% [markdown]
# # EDA - 2020 Kaggle Machine Learning and Data Science Survey

# %% [markdown]
# ### 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Importing Dataset

# %%
df = pd.read_csv('kaggle_survey_2020_responses.csv')
# Out:
# C:\Users\yasha\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                    1838                        35-39
# 2                                  289287                        30-34
# 3                                     860                        35-39
# 4                                     507                        30-34
# ...                                   ...                          ...
# 20032                                 126                        18-21
# 20033                                 566                        55-59
# 20034                                 238                        30-34
# 20035                                 625                        22-24
# 20036                                1031                        22-24
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# ...

# %% [markdown]
# ### 3. Data Preparation and Cleaning

# %% [markdown]
# ##### Taking the questions out from dataset

# %%
questions = df.iloc[0]

# %%
questions
# Out:
# Time from Start to Finish (seconds)                                Duration (in seconds)
# Q1                                                           What is your age (# years)?
# Q2                                                What is your gender? - Selected Choice
# Q3                                             In which country do you currently reside?
# Q4                                     What is the highest level of formal education ...
#                                                              ...
# Q35_B_Part_7                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_8                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_9                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_10                          In the next 2 years, do you hope to become mor...
# Q35_B_OTHER                            In the next 2 years, do you hope to become mor...
# ...

# %%
df = df.iloc[1:, :]

# %%
df
# Out:
#       Time from Start to Finish (seconds)     Q1     Q2  \
# 1                                    1838  35-39    Man
# 2                                  289287  30-34    Man
# 3                                     860  35-39    Man
# 4                                     507  30-34    Man
# 5                                      78  30-34    Man
# ...                                   ...    ...    ...
# 20032                                 126  18-21    Man
# 20033                                 566  55-59  Woman
# 20034                                 238  30-34    Man
# 20035                                 625  22-24    Man
# 20036                                1031  22-24    Man
#
#                                                       Q3  \
# 1                                               Colombia
# 2                               United States of America
# 3                                              Argentina
# 4                               United States of America
# ...

# %%
df.shape
# Out:
# (20036, 355)

# %% [markdown]
# Dataset have 20036 rows and 355 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20036 entries, 1 to 20036
# Columns: 355 entries, Time from Start to Finish (seconds) to Q35_B_OTHER
# dtypes: object(355)
# memory usage: 54.3+ MB

# %% [markdown]
# ##### Statistical information about data

# %%
df.describe()
# Out:
#         Time from Start to Finish (seconds)     Q1     Q2     Q3  \
# count                                 20036  20036  20036  20036
# unique                                 5167     11      5     55
# top                                     565  25-29    Man  India
# freq                                     34   4011  15789   5851
#
#                      Q4       Q5         Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  \
# count             19569    19277      19120     15530      4277      7535
# unique                7       13          7         1         1         1
# top     Master’s degree  Student  3-5 years    Python         R       SQL
# freq               7859     5171       4546     15530      4277      7535
#
#         ...        Q35_B_Part_2 Q35_B_Part_3          Q35_B_Part_4  \
# count   ...                1177          494                   430
# unique  ...                   1            1                     1
# ...

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(df.isnull().sum())
# Out:
# Time from Start to Finish (seconds)        0
# Q1                                         0
# Q2                                         0
# Q3                                         0
# Q4                                       467
# Q5                                       759
# Q6                                       916
# Q7_Part_1                               4506
# Q7_Part_2                              15759
# Q7_Part_3                              12501
# Q7_Part_4                              16721
# Q7_Part_5                              16209
# Q7_Part_6                              16669
# Q7_Part_7                              17041
# Q7_Part_8                              19774
# Q7_Part_9                              19838
# Q7_Part_10                             18260
# Q7_Part_11                             17819
# Q7_Part_12                             19830
# Q7_OTHER                               18091
# Q8                                      2215
# ...

# %% [markdown]
# ##### Dropping some less relevant questions

# %%
df = df.drop(['Time from Start to Finish (seconds)','Q10_Part_1', 'Q10_Part_2', 'Q10_Part_3', 'Q10_Part_4', 'Q10_Part_5', 'Q10_Part_6', 'Q10_Part_7', 'Q10_Part_8', 'Q10_Part_9', 'Q10_Part_10', 'Q10_Part_11', 'Q10_Part_12', 'Q10_Part_13', 'Q10_OTHER'], axis = 1)

# %%
df.shape
# Out:
# (20036, 340)

# %%
df = df.drop(['Q12_Part_1', 'Q12_Part_2', 'Q12_Part_3', 'Q12_OTHER', 'Q13'], axis = 1)

# %%
df.shape
# Out:
# (20036, 335)

# %%
df = df.drop(['Q20', 'Q22', 'Q23_Part_1', 'Q23_Part_2', 'Q23_Part_3', 'Q23_Part_4', 'Q23_Part_5', 'Q23_Part_6', 'Q23_Part_7', 'Q23_OTHER'], axis = 1)

# %%
df.shape
# Out:
# (20036, 325)

# %%
df = df.drop(['Q27_A_Part_1', 'Q27_A_Part_2', 'Q27_A_Part_3', 'Q27_A_Part_4', 'Q27_A_Part_5', 'Q27_A_Part_6', 'Q27_A_Part_7', 'Q27_A_Part_8', 'Q27_A_Part_9', 'Q27_A_Part_10', 'Q27_A_Part_11', 'Q27_A_OTHER',
             'Q28_A_Part_1', 'Q28_A_Part_2', 'Q28_A_Part_3', 'Q28_A_Part_4', 'Q28_A_Part_5', 'Q28_A_Part_6', 'Q28_A_Part_7', 'Q28_A_Part_8', 'Q28_A_Part_9', 'Q28_A_Part_10', 'Q28_A_OTHER', 'Q30', 'Q32',
             'Q34_A_Part_1', 'Q34_A_Part_2', 'Q34_A_Part_3', 'Q34_A_Part_4', 'Q34_A_Part_5', 'Q34_A_Part_6', 'Q34_A_Part_7', 'Q34_A_Part_8', 'Q34_A_Part_9', 'Q34_A_Part_10', 'Q34_A_Part_11', 'Q34_A_OTHER', 'Q38'], axis = 1)

# %%
df.shape
# Out:
# (20036, 287)

# %%
df = df.drop(['Q26_B_Part_1', 'Q26_B_Part_2', 'Q26_B_Part_3', 'Q26_B_Part_4', 'Q26_B_Part_5', 'Q26_B_Part_6', 'Q26_B_Part_7', 'Q26_B_Part_8', 'Q26_B_Part_9', 'Q26_B_Part_10', 'Q26_B_Part_11', 'Q26_B_OTHER',
             'Q27_B_Part_1', 'Q27_B_Part_2', 'Q27_B_Part_3', 'Q27_B_Part_4', 'Q27_B_Part_5', 'Q27_B_Part_6', 'Q27_B_Part_7', 'Q27_B_Part_8', 'Q27_B_Part_9', 'Q27_B_Part_10', 'Q27_B_Part_11', 'Q27_B_OTHER',
             'Q28_B_Part_1', 'Q28_B_Part_2', 'Q28_B_Part_3', 'Q28_B_Part_4', 'Q28_B_Part_5', 'Q28_B_Part_6', 'Q28_B_Part_7', 'Q28_B_Part_8', 'Q28_B_Part_9', 'Q28_B_Part_10', 'Q28_B_OTHER',
             'Q29_B_Part_1', 'Q29_B_Part_2', 'Q29_B_Part_3', 'Q29_B_Part_4', 'Q29_B_Part_5', 'Q29_B_Part_6', 'Q29_B_Part_7', 'Q29_B_Part_8', 'Q29_B_Part_9', 'Q29_B_Part_10', 'Q29_B_Part_11', 'Q29_B_Part_12', 'Q29_B_Part_13', 'Q29_B_Part_14', 'Q29_B_Part_15', 'Q29_B_Part_16', 'Q29_B_Part_17', 'Q29_B_OTHER',
             'Q31_B_Part_1', 'Q31_B_Part_2', 'Q31_B_Part_3', 'Q31_B_Part_4', 'Q31_B_Part_5', 'Q31_B_Part_6', 'Q31_B_Part_7', 'Q31_B_Part_8', 'Q31_B_Part_9', 'Q31_B_Part_10', 'Q31_B_Part_11', 'Q31_B_Part_12', 'Q31_B_Part_13', 'Q31_B_Part_14', 'Q31_B_OTHER',
             'Q33_B_Part_1', 'Q33_B_Part_2', 'Q33_B_Part_3', 'Q33_B_Part_4', 'Q33_B_Part_5', 'Q33_B_Part_6', 'Q33_B_Part_7', 'Q33_B_OTHER',
             'Q34_B_Part_1', 'Q34_B_Part_2', 'Q34_B_Part_3', 'Q34_B_Part_4', 'Q34_B_Part_5', 'Q34_B_Part_6', 'Q34_B_Part_7', 'Q34_B_Part_8', 'Q34_B_Part_9', 'Q34_B_Part_10', 'Q34_B_Part_11', 'Q34_B_OTHER',
             'Q35_B_Part_1', 'Q35_B_Part_2', 'Q35_B_Part_3', 'Q35_B_Part_4', 'Q35_B_Part_5', 'Q35_B_Part_6', 'Q35_B_Part_7', 'Q35_B_Part_8', 'Q35_B_Part_9', 'Q35_B_Part_10', 'Q35_B_OTHER',], axis = 1)

# %%
df.shape
# Out:
# (20036, 188)

# %%
df.head()
# Out:
#       Q1   Q2                        Q3                 Q4                 Q5  \
# 1  35-39  Man                  Colombia    Doctoral degree            Student
# 2  30-34  Man  United States of America    Master’s degree      Data Engineer
# 3  35-39  Man                 Argentina  Bachelor’s degree  Software Engineer
# 4  30-34  Man  United States of America    Master’s degree     Data Scientist
# 5  30-34  Man                     Japan    Master’s degree  Software Engineer
#
#             Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4  ...  \
# 1   5-10 years    Python         R       SQL         C  ...
# 2   5-10 years    Python         R       SQL       NaN  ...
# 3  10-20 years       NaN       NaN       NaN       NaN  ...
# 4   5-10 years    Python       NaN       SQL       NaN  ...
# 5    3-5 years    Python       NaN       NaN       NaN  ...
#
#                         Q39_Part_3                       Q39_Part_4  \
# ...

# %% [markdown]
# ### 4. Exploratory Analysis and Visualization

# %% [markdown]
# #### Which age group is most into Data Science and Machine Learning?

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
df.Q1.unique()
# Out:
# array(['35-39', '30-34', '22-24', '25-29', '18-21', '55-59', '50-54',
#        '40-44', '60-69', '45-49', '70+'], dtype=object)

# %%
no_of_people = df.Q1.value_counts()

# %%
no_of_people
# Out:
# 25-29    4011
# 22-24    3786
# 18-21    3469
# 30-34    2811
# 35-39    1991
# 40-44    1397
# 45-49     988
# 50-54     698
# 55-59     411
# 60-69     398
# 70+        76
# Name: Q1, dtype: int64

# %%
no_of_people.plot(kind = 'bar', color = ["#D9514EFF", "#435E55FF"], figsize=(15, 8))
plt.title("Different age groups in ML and Data Science who have given survey")
plt.ylabel("No. of people who gave the survey")
# Out:
# Text(0, 0.5, 'No. of people who gave the survey')

# %% [markdown]
# #### Gender Distribution according to Survey

# %%
df.Q2.nunique()
# Out:
# 5

# %%
df.Q2.unique()
# Out:
# array(['Man', 'Woman', 'Prefer to self-describe', 'Prefer not to say',
#        'Nonbinary'], dtype=object)

# %%
gender_distribution = df.Q2.value_counts()

# %%
gender_distribution
# Out:
# Man                        15789
# Woman                       3878
# Prefer not to say            263
# Prefer to self-describe       54
# Nonbinary                     52
# Name: Q2, dtype: int64

# %%
labels = ['Man', 'Woman', 'Prefer not to say', 'Prefer to self-describe', 'Nonbinary']
explode = (0.05,0.05,0.05,0.15, 0.27)
plt.pie(gender_distribution, labels=labels, explode=explode, startangle=60, autopct='%1.2f%%')
plt.title("How many restaurants allow table booking?")
fig = plt.gcf()
fig.set_size_inches(8, 8)
plt.legend()

# %% [markdown]
# #### Top 10 countries that have most number of Data Scientists who gave survey

# %%
df.Q3.nunique()
# Out:
# 55

# %%
DS_per_country = df.Q3.value_counts()

# %%
DS_per_country = DS_per_country[0:10]

# %%
DS_per_country
# Out:
# India                                                   5851
# United States of America                                2237
# Other                                                   1388
# Brazil                                                   694
# Japan                                                    638
# Russia                                                   582
# United Kingdom of Great Britain and Northern Ireland     489
# Nigeria                                                  476
# China                                                    474
# Germany                                                  404
# Name: Q3, dtype: int64

# %%
DS_per_country.plot(kind = 'bar', color = ["#D9514EFF", "#435E55FF"], figsize=(15, 8))
plt.title("Top 10 countries with most number of Data Scientists who gave survey")
plt.ylabel("No. of people who gave the survey")
# Out:
# Text(0, 0.5, 'No. of people who gave the survey')

# %% [markdown]
# #### Highest level of formal education that people have attained or plan to attain within the next 2 years

# %%
df.Q4.nunique()
# Out:
# 7

# %%
formal_education = df.Q4.value_counts()

# %%
formal_education
# Out:
# Master’s degree                                                      7859
# Bachelor’s degree                                                    6978
# Doctoral degree                                                      2302
# Some college/university study without earning a bachelor’s degree    1092
# Professional degree                                                   699
# I prefer not to answer                                                399
# No formal education past high school                                  240
# Name: Q4, dtype: int64

# %%
labels = ["Master’s degree", "Bachelor’s degree", "Doctoral degree", "Some college/university study without earning a bachelor’s degree", "Professional degree", "I prefer not to answer", "No formal education past high school"]
explode = (0.05,0.05,0.05,0.05, 0.05, 0.15, 0.27)
plt.pie(formal_education, labels=labels, explode = explode, startangle=60, autopct='%1.2f%%')
plt.title("Highest level of formal education that people have attained or plan to attain within the next 2 years")
fig = plt.gcf()
fig.set_size_inches(8, 8)

# %% [markdown]
# #### What is the current role or most recent role of the people who gave the survey?

# %%
df.Q5.nunique()
# Out:
# 13

# %%
df.Q5.unique()
# Out:
# array(['Student', 'Data Engineer', 'Software Engineer', 'Data Scientist',
#        'Data Analyst', 'Research Scientist', 'Other',
#        'Currently not employed', 'Statistician',
#        'Product/Project Manager', 'Machine Learning Engineer', nan,
#        'Business Analyst', 'DBA/Database Engineer'], dtype=object)

# %%
current_role = df.Q5.value_counts()

# %%
current_role
# Out:
# Student                      5171
# Data Scientist               2676
# Software Engineer            1968
# Other                        1737
# Currently not employed       1652
# Data Analyst                 1475
# Research Scientist           1174
# Machine Learning Engineer    1082
# Business Analyst              798
# Product/Project Manager       692
# Data Engineer                 437
# Statistician                  290
# DBA/Database Engineer         125
# Name: Q5, dtype: int64

# %%
current_role.plot(kind = 'bar', color = ["#D9514EFF", "#435E55FF"], figsize=(15, 8))
plt.title("Current role or most recent role of the people who gave the survey")
plt.ylabel("No. of people who gave the survey")
# Out:
# Text(0, 0.5, 'No. of people who gave the survey')

# %% [markdown]
# #### For how many years are they writing code and/or programming?

# %%
df.Q6.unique()
# Out:
# array(['5-10 years', '10-20 years', '3-5 years', '< 1 years', '1-2 years',
#        '20+ years', 'I have never written code', nan], dtype=object)

# %%
write_program = df.Q6.value_counts()
write_program
# Out:
# 3-5 years                    4546
# 1-2 years                    4505
# < 1 years                    3313
# 5-10 years                   2552
# 10-20 years                  1751
# 20+ years                    1329
# I have never written code    1124
# Name: Q6, dtype: int64

# %%
labels = ["3-5 years", "1-2 years", "< 1 years", "5 - 10 years", "10 - 20 years", "20 + years", "I have never written code"]
explode = (0.05,0.05,0.05,0.05, 0.05, 0.05, 0.05)
plt.pie(write_program, labels=labels, explode = explode, startangle=60, autopct='%1.2f%%')
plt.title("For how many years are they writing code and/or programming?")
fig = plt.gcf()
fig.set_size_inches(8, 8)

# %% [markdown]
# #### Which programming languages are they using regularly?

# %%
df.columns.get_loc("Q7_Part_1")
# Out:
# 6

# %%
df.columns.get_loc("Q7_OTHER")
# Out:
# 18

# %% [markdown]
# Therefore our data for "Which programming languages are they using regularly?" lies between column 6 to 18 in DataFrame

# %%
df.iloc[:, 6:19]
# Out:
#       Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6   Q7_Part_7  \
# 1        Python         R       SQL         C       NaN       NaN  Javascript
# 2        Python         R       SQL       NaN       NaN       NaN         NaN
# 3           NaN       NaN       NaN       NaN       NaN      Java  Javascript
# 4        Python       NaN       SQL       NaN       NaN       NaN         NaN
# 5        Python       NaN       NaN       NaN       NaN       NaN         NaN
# ...         ...       ...       ...       ...       ...       ...         ...
# 20032       NaN       NaN       NaN       NaN       NaN       NaN         NaN
# 20033    Python       NaN       NaN       NaN       NaN       NaN         NaN
# 20034    Python       NaN       NaN       NaN       NaN       NaN         NaN
# 20035    Python       NaN       SQL         C       NaN      Java  Javascript
# 20036    Python       NaN       NaN       NaN       NaN       NaN         NaN
#
# ...

# %%
l = {}
for i in range (1, 13):
    l.update(dict(df[f'Q7_Part_{i}'].value_counts()))

# %%
l
# Out:
# {'Python': 15530,
#  'R': 4277,
#  'SQL': 7535,
#  'C': 3315,
#  'C++': 3827,
#  'Java': 3367,
#  'Javascript': 2995,
#  'Julia': 262,
#  'Swift': 198,
#  'Bash': 1776,
#  'MATLAB': 2217,
#  'None': 206}

# %%
language = list(l.keys())
total = list(l.values())

# %%
fig = plt.figure(figsize = (15, 8))
plt.bar(range(len(l)), total, tick_label=language, color = ["#D9514EFF", "#435E55FF"])
plt.title("Programming language that people use most often in ML and Data Science")
plt.ylabel("No. of people")
# Out:
# Text(0, 0.5, 'No. of people')

# %% [markdown]
# #### Which programming language do people recommend an aspiring data scientist to learn first?

# %%
df['Q8'].unique()
# Out:
# array(['Python', 'R', 'C++', 'SQL', nan, 'Java', 'MATLAB', 'C', 'Other',
#        'Javascript', 'Julia', 'None', 'Swift', 'Bash'], dtype=object)

# %%
lang_recommend = df['Q8'].value_counts()

# %%
lang_recommend
# Out:
# Python        14241
# R              1259
# SQL             849
# C++             325
# C               301
# MATLAB          195
# Java            167
# Other           151
# Julia           121
# Javascript       88
# None             81
# Bash             26
# Swift            17
# Name: Q8, dtype: int64

# %%
lang_recommend.plot(kind = 'bar', color = ["#D9514EFF", "#435E55FF"], figsize=(15, 8))
plt.title("Programming language that people recommend an aspiring data scientist to learn first")
plt.ylabel("People who recommend")
# Out:
# Text(0, 0.5, 'People who recommend')

# %% [markdown]
# #### Which IDE do people use the most for ML and Data Science?

# %%
ide = {}
for i in range (1, 12):
    ide.update(dict(df[f'Q9_Part_{i}'].value_counts()))

# %%
ide
# Out:
# {'Jupyter (JupyterLab, Jupyter Notebooks, etc) ': 11211,
#  ' RStudio ': 3826,
#  'Visual Studio': 2445,
#  'Visual Studio Code (VSCode)': 5873,
#  ' PyCharm ': 5099,
#  '  Spyder  ': 3290,
#  '  Notepad++  ': 3132,
#  '  Sublime Text  ': 2452,
#  '  Vim / Emacs  ': 1502,
#  ' MATLAB ': 1604,
#  'None': 386}

# %%
ide_name = list(ide.keys())
total_ide_use = list(ide.values())

# %%
fig = plt.figure(figsize = (15, 8))
plt.bar(range(len(ide)), total_ide_use, tick_label=ide_name, color = ["#D9514EFF", "#435E55FF"])
plt.title("IDE that people use most often for ML and Data Science")
plt.ylabel("No. of people")
# Out:
# Text(0, 0.5, 'No. of people')

# %% [markdown]
# #### What data visualization libraries or tools do people use on a regular basis?

# %%
viz_lib = {}
for i in range (1, 12):
    viz_lib.update(dict(df[f'Q14_Part_{i}'].value_counts()))

# %%
viz_lib
# Out:
# {' Matplotlib ': 12342,
#  ' Seaborn ': 8821,
#  ' Plotly / Plotly Express ': 4130,
#  ' Ggplot / ggplot2 ': 4120,
#  ' Shiny ': 1137,
#  ' D3 js ': 829,
#  ' Altair ': 233,
#  ' Bokeh ': 920,
#  ' Geoplotlib ': 850,
#  ' Leaflet / Folium ': 596,
#  'None': 1897}

# %%
viz_lib_name = list(viz_lib.keys())
total_viz_lib_use = list(viz_lib.values())

# %%
labels = ["Matplotlib", "Seaborn", "Plotly / Plotly Express", "Ggplot / ggplot2", "Shiny", "D3 js", "Altair", "Bokeh", "Geoplotlib", "Leaflet / Folium", "None"]
explode = (0.05, 0.05, 0.05, 0.05, 0.08, 0.11, 0.14, 0.17, 0.20, 0.23, 0.26)
plt.pie(total_viz_lib_use, explode = explode,labels=labels, startangle=60, autopct='%1.2f%%')
plt.title("Data Visualisation library that people use on regular basis")
fig = plt.gcf()
fig.set_size_inches(8, 8)

# %% [markdown]
# #### Which machine learning frameworks do people use on a regular basis?

# %%
ml_framework = {}
for i in range (1, 16):
    ml_framework.update(dict(df[f'Q16_Part_{i}'].value_counts()))

# %%
ml_framework
# Out:
# {'  Scikit-learn ': 10250,
#  '  TensorFlow ': 6934,
#  ' Keras ': 6192,
#  ' PyTorch ': 4189,
#  ' Fast.ai ': 742,
#  ' MXNet ': 218,
#  ' Xgboost ': 3935,
#  ' LightGBM ': 1799,
#  ' CatBoost ': 957,
#  ' Prophet ': 532,
#  ' H2O 3 ': 344,
#  ' Caret ': 939,
#  ' Tidymodels ': 484,
#  ' JAX ': 84,
#  'None': 1208}

# %%
ml_fram_name = list(ml_framework.keys())
total_ml_fram_use = list(ml_framework.values())

# %%
labels = ["Scikit-learn", "TensorFlow", "Keras", "Pytorch", "Fast.ai", "MXNet", "Xgboost", "LightGBM", "CatBoost", "Prophet", "H20 3", "Caret", "Tidymodels", "JAX", "None"]
explode = (0.05, 0.05, 0.05, 0.05, 0.08, 0.11, 0.14, 0.17, 0.20, 0.23, 0.26, 0.29, 0.33, 0.37, 0.41)
plt.pie(total_ml_fram_use, explode = explode,labels=labels, startangle=180, autopct='%1.2f%%')
plt.title("Machine Learning Frameworks that people use regularly")
fig = plt.gcf()
fig.set_size_inches(8, 8)

# %% [markdown]
# #### Which Machine Learning algorithms do people use on a regular basis?

# %%
ml_algo = {}
for i in range (1, 12):
    ml_algo.update(dict(df[f'Q17_Part_{i}'].value_counts()))
ml_algo
# Out:
# {'Linear or Logistic Regression': 10560,
#  'Decision Trees or Random Forests': 8804,
#  'Gradient Boosting Machines (xgboost, lightgbm, etc)': 5134,
#  'Bayesian Approaches': 3647,
#  'Evolutionary Approaches': 731,
#  'Dense Neural Networks (MLPs, etc)': 3364,
#  'Convolutional Neural Networks': 5859,
#  'Generative Adversarial Networks': 1024,
#  'Recurrent Neural Networks': 3468,
#  'Transformer Networks (BERT, gpt-3, etc)': 1298,
#  'None': 736}

# %%
ml_algo_name = list(ml_algo.keys())
total_ml_algo_use = list(ml_algo.values())

# %%
labels = ["Linear or Logistic Regression", "Decision Trees or Random Forests", "Gradient Boosting Machines (xgboost, lightgbm, etc)", "Bayesian Approaches", "Evolutionary Approaches", "Dense Neural Networks (MLPs, etc)", "Convolutional Neural Networks", "Generative Adversarial Networks", "Recurrent Neural Networks", "Transformer Networks (BERT, gpt-3, etc)", "None"]
explode = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05)
plt.pie(total_ml_algo_use, explode = explode,labels=labels, startangle=180, autopct='%1.2f%%')
plt.title("Machine Learning Frameworks that people use regularly")
fig = plt.gcf()
fig.set_size_inches(8, 8)

# %% [markdown]
# #### Which categories of computer vision methods people use on a regular basis?

# %%
cv_methods = {}
for i in range (1, 7):
    cv_methods.update(dict(df[f'Q18_Part_{i}'].value_counts()))
cv_methods
# Out:
# {'General purpose image/video tools (PIL, cv2, skimage, etc)': 2139,
#  'Image segmentation methods (U-Net, Mask R-CNN, etc)': 2003,
#  'Object detection methods (YOLOv3, RetinaNet, etc)': 2079,
#  'Image classification and other general purpose networks (VGG, Inception, ResNet, ResNeXt, NASNet, EfficientNet, etc)': 3512,
#  'Generative Networks (GAN, VAE, etc)': 1092,
#  'None': 1153}

# %%
cv_methods_name = list(cv_methods.keys())
total_cv_methods_use = list(cv_methods.values())

# %%
labels = ["General purpose image/video tools (PIL, cv2, skimage, etc)", "Image segmentation methods (U-Net, Mask R-CNN, etc)", "Object detection methods (YOLOv3, RetinaNet, etc)", "Image classification and other general purpose networks (VGG, Inception, ResNet, ResNeXt, NASNet, EfficientNet, etc)", "Generative Networks (GAN, VAE, etc)", "None"]
explode = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05)
plt.pie(total_cv_methods_use, explode = explode,labels=labels, startangle=180, autopct='%1.2f%%')
centre_circle = plt.Circle((0, 0.0), 0.70, fc='white')
plt.title("Computer Vision methods that people use regularly")
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
fig.set_size_inches(8, 8)

# %% [markdown]
# #### Which natural language processing (NLP) methods people use on a regular basis?

# %%
nlp_methods = {}
for i in range (1, 6):
    nlp_methods.update(dict(df[f'Q19_Part_{i}'].value_counts()))
nlp_methods
# Out:
# {'Word embeddings/vectors (GLoVe, fastText, word2vec)': 2110,
#  'Encoder-decorder models (seq2seq, vanilla transformers)': 1514,
#  'Contextualized embeddings (ELMo, CoVe)': 557,
#  'Transformer language models (GPT-3, BERT, XLnet, etc)': 1428,
#  'None': 1047}

# %%
nlp_methods_name = list(nlp_methods.keys())
total_nlp_methods_use = list(nlp_methods.values())

# %%
labels = ["Word embeddings/vectors (GLoVe, fastText, word2vec)", "Encoder-decorder models (seq2seq, vanilla transformers)", "Contextualized embeddings (ELMo, CoVe)", "Transformer language models (GPT-3, BERT, XLnet, etc)", "None"]
explode = (0.05, 0.05, 0.05, 0.05, 0.05)
plt.pie(total_nlp_methods_use, explode = explode, labels=labels, startangle=180, autopct='%1.2f%%')
centre_circle = plt.Circle((0, 0.0), 0.70, fc='white')
plt.title("Natural Language Processing(NLP) methods that people use regularly")
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
fig.set_size_inches(8, 8)

# %% [markdown]
# #### What is the most common yearly compensation and what is the least common yearly compensation of the people who gave the survey?

# %%
df.Q24.nunique()
# Out:
# 25

# %%
df.Q24.unique()
# Out:
# array([nan, '100,000-124,999', '15,000-19,999', '125,000-149,999',
#        '70,000-79,999', '30,000-39,999', '90,000-99,999', '1,000-1,999',
#        '$0-999', '10,000-14,999', '150,000-199,999', '60,000-69,999',
#        '4,000-4,999', '> $500,000', '300,000-500,000', '40,000-49,999',
#        '25,000-29,999', '80,000-89,999', '7,500-9,999', '50,000-59,999',
#        '250,000-299,999', '5,000-7,499', '2,000-2,999', '20,000-24,999',
#        '200,000-249,999', '3,000-3,999'], dtype=object)

# %%
total_compensation = df.Q24.value_counts()
total_compensation
# Out:
# $0-999             2128
# 10,000-14,999       665
# 1,000-1,999         581
# 100,000-124,999     573
# 40,000-49,999       552
# 30,000-39,999       540
# 50,000-59,999       510
# 5,000-7,499         488
# 15,000-19,999       449
# 60,000-69,999       408
# 20,000-24,999       404
# 70,000-79,999       394
# 7,500-9,999         371
# 150,000-199,999     347
# 2,000-2,999         330
# 125,000-149,999     315
# 25,000-29,999       310
# 90,000-99,999       280
# 4,000-4,999         279
# 80,000-89,999       273
# 3,000-3,999         264
# 200,000-249,999     115
# 300,000-500,000      55
# > $500,000           50
# 250,000-299,999      48
# Name: Q24, dtype: int64

# %%
total_compensation.plot(kind = 'bar', color = ["#D9514EFF", "#435E55FF"], figsize=(15, 8))
plt.title("Programming language that people recommend an aspiring data scientist to learn first")
plt.ylabel("People who recommend")
# Out:
# Text(0, 0.5, 'People who recommend')

# %% [markdown]
# #### Which cloud computing platforms do people use on a regular basis?

# %%
cc_methods = {}
for i in range (1, 12):
    cc_methods.update(dict(df[f'Q26_A_Part_{i}'].value_counts()))
cc_methods
# Out:
# {' Amazon Web Services (AWS) ': 2806,
#  ' Microsoft Azure ': 1705,
#  ' Google Cloud Platform (GCP) ': 2286,
#  ' IBM Cloud / Red Hat ': 441,
#  ' Oracle Cloud ': 286,
#  ' SAP Cloud ': 169,
#  ' Salesforce Cloud ': 192,
#  ' VMware Cloud ': 248,
#  ' Alibaba Cloud ': 115,
#  ' Tencent Cloud ': 76,
#  'None': 1837}

# %%
cc_platform_name = list(cc_methods.keys())
total_cc_platform_use = list(cc_methods.values())

# %%
labels = ["Amazon Web Services (AWS)", "Microsoft Azure", "Google Cloud Platform (GCP)", "IBM Cloud / Red Hat", "Oracle Cloud", "SAP Cloud", "Salesforce Cloud", "VMware Cloud", "Alibaba Cloud", "Tencent Cloud", "None"]
explode = (0.05, 0.05, 0.05, 0.05, 0.05, 0.1, 0.05, 0.17, 0.05, 0.19, 0.05)
plt.pie(total_cc_platform_use, explode = explode,labels=labels, startangle=180, autopct='%1.2f%%')
plt.title("Cloud Computing platforms that people use regularly")
fig = plt.gcf()
fig.set_size_inches(8, 8)

# %% [markdown]
# #### Which big data products (relational databases, data warehouses, data lakes, or similar) do people use on a regular basis?

# %%
bd_products = {}
for i in range (1, 18):
    bd_products.update(dict(df[f'Q29_A_Part_{i}'].value_counts()))
bd_products
# Out:
# {'MySQL ': 2488,
#  'PostgresSQL ': 1675,
#  'SQLite ': 1176,
#  'Oracle Database ': 956,
#  'MongoDB ': 1264,
#  'Snowflake ': 273,
#  'IBM Db2 ': 270,
#  'Microsoft SQL Server ': 1558,
#  'Microsoft Access ': 465,
#  'Microsoft Azure Data Lake Storage ': 434,
#  'Amazon Redshift ': 443,
#  'Amazon Athena ': 309,
#  'Amazon DynamoDB ': 410,
#  'Google Cloud BigQuery ': 669,
#  'Google Cloud SQL ': 429,
#  'Google Cloud Firestore ': 243,
#  'None': 1494}

# %%
bd_products_name = list(bd_products.keys())
total_bd_products_use = list(bd_products.values())

# %%
labels = ["MySQl", "PostgresSQL", "SQLite", "Oracle Database", "MongoDB", "Snowflake", "IBM Db2", "Microsoft SQL Server", "Microsoft Access", "Microsoft Azure Data Lake Storage", "Amazon Redshift", "Amazon Athena", "Amazon DynamoDB", "Google Cloud BigQuery", "Google Cloud SQL", "Google Cloud Firestore", "None"]
explode = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05)
plt.pie(total_bd_products_use, explode = explode, labels=labels, startangle=180, autopct='%1.2f%%')
centre_circle = plt.Circle((0, 0.0), 0.70, fc='white')
plt.title("Big Data products that people use regularly")
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
fig.set_size_inches(8, 8)

# %% [markdown]
# #### Where do people publicly share or deploy their data analysis or machine learning applications?

# %%
share_deploy = {}
for i in range (1, 10):
    share_deploy.update(dict(df[f'Q36_Part_{i}'].value_counts()))
share_deploy
# Out:
# {' Plotly Dash ': 227,
#  ' Streamlit ': 186,
#  ' NBViewer ': 92,
#  ' GitHub ': 3434,
#  ' Personal blog ': 527,
#  ' Kaggle ': 1878,
#  ' Colab ': 1247,
#  ' Shiny ': 332,
#  'I do not share my work publicly': 2317}

# %%
share_deploy_name = list(share_deploy.keys())
total_share_deploy_use = list(share_deploy.values())

# %%
labels = ["Plotly Dash", "Streamlit", "NBViewer", "GitHub", "Personal blog", "Kaggle", "Colab", "Shiny", "I do not share my work publicly"]
explode = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05)
plt.pie(total_share_deploy_use, explode = explode,labels=labels, startangle=180, autopct='%1.2f%%')
plt.title("Where do people publically share or deploy their data analysis or machine learning applications?")
fig = plt.gcf()
fig.set_size_inches(8, 8)

# %% [markdown]
# ### 5. Ask and Answer Questions

# %% [markdown]
# #### Which age group is most into Data Science and Machine Learning?
# According to survey, people with age 25-29 are more into ML and Data Science followed by age group 22-24 and 18-21 respectively.

# %% [markdown]
# #### What is the gender distribution in ML and Data Science domain as per survey?
# According to survey, 78.80% people who work in ML and Data Science are men, 19.36% are women, 1.31% preferred not to say, 0.27% preferred to self describe and 0.26% are nonbinary.

# %% [markdown]
# #### Which are the top 5 countries with most number of people in ML and Data Science?
# 'India' is the country with most number of people i.e 5851 people in ML and Data Science followed by 'United States of America' with 2237, 'Brazil' with 1388, 'Japan' with 694, 'Russia' with 638 people who gave survey.

# %% [markdown]
# #### What is the highest level of formal education that people have attained or plan to attain within the next 2 years?
# 40.16% of people have attained or planning to attain Master's Degree, 35.66% of people have attained or planning to attain Batchelor's Degree followed by 11.76% of people have attained or planning to attain Doctoral degree, 3.57% of people have attained or planning to attain a Professional Degree, 5.58% of people have attained or planning to attain some college/university study without earning a bachelor’s degree, 1.23% have no formal education after high school and 2.04% people choose not to answer

# %% [markdown]
# #### What is the current role or most recent role of the people who gave the survey?
# Out of 20036 people who gave the survey, 5171 are Students, 2676 are Data Scientists, 1968 are Software Engineers, 1652 are currently not employed, 1457 are Data Analysts and so on.

# %% [markdown]
# #### For how many years are they writing code and/or programming?
# 23.78% of people who have given the survey are writing code for 3-5 years, 23.56% of them are writing code for 1-2 years, 17.33% for less than 1 year, 13.35% for 5-10 years, 9.16% for 10-20 years, 6.95% for more than 20 years and 5.88% have never written the code.

# %% [markdown]
# #### Which top 3 programming language do people use more regularly?
# 15530 people choose 'Python' as a programming language that comes in use more regularly, 7535 choose 'SQL' and 4277 people choose 'R'.

# %% [markdown]
# #### Which are the top 3 IDEs that people use for ML and Data Science?
# 'Jupyter (JupyterLab, Jupyter Notebooks, etc)' is the most popular IDE that over 11211 people choose, followed by 'Visual Studio Code' with 5873 people and then 'Pycharm' with 5099 people.

# %% [markdown]
# #### Which are the top 3 data visualization libraries or tools that people use on a regular basis?
# 34.40 % of people choose 'Matplotlib', 24.59 % of people choose 'Seaborn' and 11.51 % of people choose 'Plotly / Plotly Express' as the top 3 data visualization libraries or tools that they use on a regular basis.

# %% [markdown]
# #### Which are the top 3 Machine Learning Frameworks that people use on regular basis?
# 26.41 % of people choose 'Scikit learn', 17.87 % of people choose 'Tensorflow' and 15.96 % of people choose 'Keras' as the top 3 Machine Learning frameworks that they use on a regular basis.

# %% [markdown]
# #### Which are the top 3 Machine Learning Algorithms that people use on regular basis?
# 23.66 % of people choose 'Linear or Logistic regression', 19.73 % of people choose 'Decision Trees or Random Forests' and 13.13 % of people choose 'Convolutional Neural Network' as the top 3 Machine Learining algorithms that they use on regular basis.

# %% [markdown]
# #### Which are the top 3 Computer Vision methods that people use on regular basis?
# 29.32 % of people choose 'Image classification and other general purpose networks (VGG, Inception, ResNet, ResNeXt, NASNet, EfficientNet, etc)', 17.86 % of people choose 'General purpose image/video tools (PIL, cv2, skimage, etc)' and 17.36 % people choose 'Object detection methods (YOLOv3, RetinaNet, etc)' as the top 3 Computer Vision algorithms that they use on regular basis.

# %% [markdown]
# #### Which are the top 3 Natural Language Processing (NLP) methods that people use on regular basis?
# 31.70 % of people choose 'Word embeddings/vectors (GLoVe, fastText, word2vec)', 22.75 % of people choose 'Encoder-decorder models (seq2seq, vanilla transformers)' and 21.45 % people choose 'Transformer language models (GPT-3, BERT, XLnet, etc)' as the top 3 Natural Language Processing (NLP) algorithms that they use on regular basis.

# %% [markdown]
# #### What is the most common yearly compensation and what is the least common yearly compensation of the people who gave the survey?
# The most common yearly compensation is 0-999 dollars with 2128 people and the least common yearly compensation is 250,000-299,999 dollars with 48 people

# %% [markdown]
# #### Which are the top 3 Cloud Computing platforms that people use on regular basis?
# 27.62 % of people choose 'Amazon Web Services (AWS)', 22.50 % of people choose 'Google Cloud Platform (GCP)' and 16.78 % of people choose 'Microsoft Azure' as the top 3 Cloud Computing platforms that they use on regualr basis.

# %% [markdown]
# #### Which are the top 3 big data products that people use on regular basis?
# 17.09 % of people choose 'MySQL', 11.51 % of people choose 'PostgresSQL' and 10.70 % of people choose 'Microsoft SQL Server' as the top 3 big data products that they use on regular basis.

# %% [markdown]
# #### Where do people publically share or deploy their data analysis or machine learning applications (top 3)?
# 33.54 % of people choose 'Github', 18.34 % of people choose 'Kaggle' and 12.18 % of people choose 'Colab' as the top three places where they publically share or deploy their data analysis or machine learning applications.
